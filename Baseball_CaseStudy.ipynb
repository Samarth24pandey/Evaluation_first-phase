# %% [markdown]
# #                      Baseball Case Study
# # Project Description
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.

# %% [markdown]
# # Importing necessary Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
from sklearn.linear_model import Ridge,Lasso,ElasticNet
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import SGDRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
# Importing data

# %%
df = pd.read_csv("baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
print(f"The rows and columns in the dataset:{df.shape}")
print(f"\n The column headers in the dataset:{df.columns}")
# Out:
# The rows and columns in the dataset:(30, 17)
#
#  The column headers in the dataset:Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# #The columns headers are denoted as follows
# 1. W - This indicates the number of Wins credited to a pitcher
# 2. R - This indicates Runs scored
# 3. AB - This means At bat or time at bat
# 4. H - This means Hit
# 5. 2B - This means "two-base hit"
# 6. 3B - This measns a Triple
# 7. HR- This means Home runs
# 8. BB- This means base on balls/"Walk"
# 9. SO- This means Strikeout
# 10.SB- This means Stolen base
# 11.RA- This means Run Average
# 12.ER- This means Earned Run
# 13.ERA- This means Earned run Average
# 14.CG- This means Complete Game
# 15.SHO- This means Shoutout
# 16.SV- This means Save
# 17.E- This means Errors

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# WE can see that the data is accurate and we do not need to change the datatype.

# %%
#Checking Null values

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df.shape
# Out:
# (30, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# # Checking for duplicate values

# %%
duplicate = df[df.duplicated()]
print("Duplicate Rows :")

# Print the resultant Dataframe
duplicate
# Out:
# Duplicate Rows :
# Empty DataFrame
# Columns: [W, R, AB, H, 2B, 3B, HR, BB, SO, SB, RA, ER, ERA, CG, SHO, SV, E]
# Index: []

# %% [markdown]
# There is no duplicate value is the data set

# %%
# Check the descriptive statistics about data set

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# # Performing EDA Visualisation

# %%
def EDA(df,i): # create a function for Continous variables
    plt.figure(figsize=(20,5),facecolor='#FFCBA4')
    plt.subplot(1,3,1)
    sns.histplot(x=i,data=df,kde=True)
    plt.subplot(1,3,2)
    sns.regplot(x=i,y='W',data=df)
    plt.subplot(1,3,3)
    sns.boxplot(y=i,data=df)
    plt.show()

# %%
EDA(df,'R')

# %%
EDA(df,'AB')

# %%
EDA(df,'H')

# %%
EDA(df,'2B')

# %%
EDA(df,'3B')

# %%
EDA(df,'HR')

# %%
EDA(df,'BB')

# %%
EDA(df,'SO')

# %%
EDA(df,'RA')

# %%
EDA(df,'ER')

# %%
EDA(df,'ERA')

# %%
EDA(df,'CG')

# %%
EDA(df,'SHO')

# %%
EDA(df,'SV')

# %%
EDA(df,'E')

# %% [markdown]
# #After this data analysis we can say that :
# The number of home runs,runs, doubles, shutouts,saves and walks are all strongly positively correlated.
#
# Stolen bases, runs allowed, and earned runs are all highly negative linearly correlated.
#
# The other features have less linear correlation with no of Wins

# %%
# Outlier Treatment

# %%
# Removing the outlier by using Zscore Method

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
thresold=3
df1=df[(z<3).all(axis=1)]
print('percentage of loss of data by zscore is :',(df.shape[0]-df1.shape[0])/df.shape[0])
# Out:
# percentage of loss of data by zscore is : 0.03333333333333333

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
# Separating features and label

# %%
features = df1.drop('W',axis=1)
label = df1.W

# %%
# Data SCaling Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# %%
scaled_features.shape
# Out:
# (29, 16)

# %%
features.shape
# Out:
# (29, 16)

# %%
# Checking for the multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif['vif']= [variance_inflation_factor (scaled_features,i) for i in range(scaled_features.shape[1])]
vif['Features']= features.columns

# %%
vif
# Out:
#             vif Features
# 0      7.229564        R
# 1     18.333377       AB
# 2     10.558458        H
# 3      3.743423       2B
# 4      3.278636       3B
# 5      8.426403       HR
# 6      3.431971       BB
# 7      2.720640       SO
# 8      2.110804       SB
# 9    197.315706       RA
# 10  1825.871631       ER
# 11  1438.816208      ERA
# 12     3.074115       CG
# 13     3.673885      SHO
# 14     6.236487       SV
# 15     2.180914        E

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df1.corr(),annot=True,linewidths=0.1,linecolor='black',fmt='0.2f')
# Out:
# <AxesSubplot:>

# %%
# NOw we will select highly correlated features, it will remove the first feature that is correlated with other features.

def correlation(dataset, threshold):
    col_corr = set()
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j]) > threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(df1, 0.5)
len(set(corr_features))
# Out:
# 9

# %%
corr_features
# Out:
# {'2B', '3B', 'ER', 'ERA', 'H', 'HR', 'RA', 'SHO', 'SV'}

# %%
# Correlation of column with the target column

# %%
df1.corr()['W'].sort_values()
# Out:
# ERA   -0.826952
# RA    -0.823176
# ER    -0.815308
# 3B    -0.206737
# SB    -0.169503
# AB    -0.085780
# E     -0.072858
# H     -0.018360
# CG     0.029594
# SO     0.156469
# HR     0.245697
# 2B     0.384886
# R      0.390451
# BB     0.447513
# SHO    0.497526
# SV     0.749290
# W      1.000000
# Name: W, dtype: float64

# %%
df1.corr()['W'].sort_values().plot(kind='bar',grid=True,figsize=(10,7),title='Correlation with target')
# Out:
# <AxesSubplot:title={'center':'Correlation with target'}>

# %%
features = df1.drop(columns=['W','AB','H','3B','SO','SB','RA','ER','CG','E'], axis=1)
labels = df1.W

# %%
scaler = StandardScaler()
scaler_features = scaler.fit_transform(f)

# %%
maxAccu=0
lrm=LinearRegression()
maxRs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(scaled_features,l,test_size=0.3,random_state=i)
    lrm = LinearRegression()
    lrm.fit(x_train,y_train)
    pred=lrm.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('The best accuracy is ', maxAccu,'on random state',maxRS)
# Out:
# The best accuracy is  0.9125242537047676 on random state 104

# %%
x_train,x_test,y_train,y_test=train_test_split(scaled_features,l,test_size=0.3,random_state=30)

# %%
lrm = LinearRegression()
lrm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
df.tail(4)
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
# When we have multiple feature we need to check Adjusted R2 score

print('Model accuracy score on training data is ', lrm.score(x_train,y_train))
print('Model accuracy score on testing data is', lrm.score(x_test,y_test))
# Out:
# Model accuracy score on training data is  0.9515570349651229
# Model accuracy score on testing data is 0.5659207485853006

# %%
y_pred = lrm.predict(x_test)
y_pred
# Out:
# array([97.45105622, 90.10453879, 75.26056313, 87.39276533, 56.49923493,
#        96.66436277, 79.5732298 , 86.22812041, 89.26654588])

# %%
plt.scatter(y_test,y_pred)
plt.xlabel('Actual Chance of Win')
plt.ylabel('Prediction Chance of Win')
plt.title('Actual vs model prediction')
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
y_pred = lrm.predict(x_test)

# %%
print('mean_absolute_error is ', mean_absolute_error(y_test,y_pred))
print('mean_squared_error is', mean_squared_error(y_test,y_pred))
print('mean_squared_error is',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# mean_absolute_error is  4.942846327132636
# mean_squared_error is 46.69835304725543
# mean_squared_error is 6.8336193226763395

# %%
from sklearn.linear_model import Ridge, Lasso, RidgeCV, LassoCV

# %% [markdown]
# # 1) Lasso(Least Absolute Shrinkage and Selection Operator)/L1 form

# %%
lasscv = LassoCV(alphas = None, max_iter = 100, normalize = True)
lasscv.fit(x_train,y_train)
# Out:
# LassoCV(max_iter=100, normalize=True)

# %%
# Best aplha parameter/best learning rate

# %%
#Splitting the data 

X= df.drop('W',axis=1)
y= df['W']

# %% [markdown]
# # Machine Learning Modeling

# %% [markdown]
# Best Score with Random state

# %%
# Define a function to try different train test folds
def model_select(model):
    max_score=0
    max_state=0
    for x in range(42,105):
        X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=x)
        md=model()
        md.fit(X_train,y_train)
        predict=md.predict(X_test)
        r2score=r2_score(y_test,predict)
        if r2score>max_score:
            max_score=r2score
            max_state=x
    print("Max score is {} with random state {}".format(max_score,max_state))

# %%
model_select(LinearRegression)
# Out:
# Max score is 0.8342767995497651 with random state 83

# %%
model_select(ElasticNet)
# Out:
# Max score is 0.8849355566252174 with random state 86

# %%
model_select(Ridge)
# Out:
# Max score is 0.8759921574014782 with random state 45

# %%
model_select(KNeighborsRegressor)
# Out:
# Max score is 0.7637138263665596 with random state 87

# %%
model_select(RandomForestRegressor)
# Out:
# Max score is 0.777810331689825 with random state 101

# %%
model_select(AdaBoostRegressor)
# Out:
# Max score is 0.8030086358313817 with random state 97

# %%
model_select(DecisionTreeRegressor)
# Out:
# Max score is 0.7178319876309912 with random state 76

# %% [markdown]
# # Ridge Regression best model

# %%
x_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.33,random_state=50)

# %% [markdown]
# RidgeCv will return best aplha and coefficient after performing 10 cross validations.

# %%
ridgecv=RidgeCV(alphas =np.arange(0.001,0.1,0.01),normalize = True)
ridgecv.fit(x_train,y_train)
# Out:
# RidgeCV(alphas=array([0.001, 0.011, 0.021, 0.031, 0.041, 0.051, 0.061, 0.071, 0.081,
#        0.091]),
#         normalize=True)

# %%
ridgecv.alpha_
# Out:
# 0.020999999999999998

# %%
ridge_model= Ridge(alpha=ridgecv.alpha_)
ridge_model.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.020999999999999998)

# %%
ridge_model.score(X_test,y_test)
# Out:
# 0.6668992833768659

# %% [markdown]
# We can see that we got the smae r2 square Ridge regression as well. So, we can say there is no overfitting.
# And by using different type of regularization we ae still getting same r2 score. Which means the model has been well trained.

# %% [markdown]
# # Saving the model

# %%
import pickle

# %%
pickle.dump(lrm,open('lrm_model','wb'))

# %% [markdown]
# The model has been succesfully built by using Linear Regression.
